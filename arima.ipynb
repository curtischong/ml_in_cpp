# %%
import pandas as pd
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("datasets/international-airline-passengers.csv")
data['date'] = pd.to_datetime(data['date'])
data.head()
# Out:
#         date  passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
data = data.sort_values('date', ascending=True)
plt.plot(data['date'], data['passengers'])
plt.xticks(rotation='vertical')
# Out:
# (array([711493., 712223., 712954., 713684., 714415., 715145., 715876.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#I can run the Box-Cox Transformation
#I might program this transformation later (it doesn't seem too hard) but rn I want to 
#https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Box-Cox_Transformation.pdf

# %%
#1st order diff
plt.plot(data['date'], data['passengers'].diff())
plt.xticks(rotation='vertical')
# Out:
# (array([711493., 712223., 712954., 713684., 714415., 715145., 715876.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#second order diff
plt.plot(data['date'], data['passengers'].diff().diff())
plt.xticks(rotation='vertical')
# Out:
# (array([711493., 712223., 712954., 713684., 714415., 715145., 715876.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#I can also do something like this
# Seasonal differentiation (12 months)
btc_month['box_diff_seasonal_12'] = btc_month.close_box - btc_month.close_box.shift(12)
print("Dickey–Fuller test: p=%f" % adfuller(btc_month.box_diff_seasonal_12[12:])[1])

# %%
#not sure how helpful this link is
#https://people.duke.edu/~rnau/411arim.htm
def autoregression(p, d, q):
    """
    p = number of autoregressive terms
    d = number of nonseasonal differences needed for stationarity
    q = number of lagged forecast errors in the prediction equation
    """
    y =
